# %% [markdown]
# # Demand over the year

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

value_counts_over_year = pd.Dataframe()

# %% [markdown]
# ### Austin

# %%
austin_trips_df = pd.read_pickle('../pickled_data/austin_df.pickled')
austin_trips_df.start_time = pd.to_datetime(
    austin_trips_df.start_time, infer_datetime_format=True)
austin_date_value_counts = austin_trips_df.start_time.dt.date.value_counts()

austin_date_value_counts_2014 = austin_date_value_counts.filter(
    like='2014').sort_index()
austin_date_value_counts_2015 = austin_date_value_counts.filter(
    like='2015').sort_index()
austin_date_value_counts_2016 = austin_date_value_counts.filter(
    like='2016').sort_index()

for dvc in [austin_date_value_counts_2014, austin_date_value_counts_2015, austin_date_value_counts_2016]:
    values = dvc.values
    plt.plot(savgol_filter(values / np.mean(values), 21, 3))

plt.show()

# %% [markdown]
# ### London

# %%
london_trips_df = pd.read_pickle('../pickled_data/london_counts_df.pickled')
ldn_counts_per_day = london_trips_df['cnt'].groupby([london_trips_df['timestamp'].dt.date]).sum()
london_date_value_counts_2015 = ldn_counts_per_day.filter(like='2015').sort_index()
london_date_value_counts_2016 = ldn_counts_per_day.filter(like='2016').sort_index()
london_date_value_counts_2017 = ldn_counts_per_day.filter(like='2017').sort_index()
# Out:
# timestamp
# 2015-01-04     9234
# 2015-01-05    20372
# 2015-01-06    20613
# 2015-01-07    21064
# 2015-01-08    15601
#               ...
# 2016-12-30    11566
# 2016-12-31    11424
# 2017-01-01     6421
# 2017-01-02    11823
# 2017-01-03    19436
# Name: cnt, Length: 730, dtype: int64
