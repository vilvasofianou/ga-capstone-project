# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (6, 4)
plt.rcParams['font.size'] = 14
import pgeocode
plt.style.use('ggplot')
sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import scipy.stats as stats

from pygeocoder import Geocoder
from pandas.api.types import CategoricalDtype

from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import KFold

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from googletrans import Translator

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # London:

# %%
London = pd.read_csv('/Users/vilvaki/Desktop/GA/bikes/london_merged.csv',encoding='utf8',engine='python')

# %% [markdown]
# "timestamp" - timestamp field for grouping the data
# "cnt" - the count of a new bike shares
# "t1" - real temperature in C
# "t2" - temperature in C "feels like"
# "hum" - humidity in percentage
# "wind_speed" - wind speed in km/h
# "weather_code" - category of the weather
# "is_holiday" - boolean field - 1 holiday / 0 non holiday
# "is_weekend" - boolean field - 1 if the day is weekend
# "season" - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weathe_code" category description:
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %%
London.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
London.sort_values(by='timestamp', inplace=True)
# London.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
London.groupby('is_holiday')['cnt'].mean().plot(kind='bar');

# %%
London['timestamp'] = pd.to_datetime(London.timestamp)

# %%
London.dtypes
# Out:
# timestamp       datetime64[ns]
# cnt                      int64
# t1                     float64
# t2                     float64
# hum                    float64
# wind_speed             float64
# weather_code           float64
# is_holiday             float64
# is_weekend             float64
# season                 float64
# dtype: object

# %%
London['Day'] = London.timestamp.dt.weekday_name
London.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season     Day
# 0         0.0         1.0     3.0  Sunday
# 1         0.0         1.0     3.0  Sunday
# 2         0.0         1.0     3.0  Sunday
# 3         0.0         1.0     3.0  Sunday
# 4         0.0         1.0     3.0  Sunday

# %%
meadian_hum = London.hum.median()
list_hum_binary = []
for i in London['hum']:
    if i > meadian_hum:
        list_hum_binary.append(1)
    else:
        list_hum_binary.append(0)
London['hum_binary'] =  list_hum_binary

# %%
sum_london_hum = London.groupby(['Day','hum_binary']).sum()
count_london_hum = London.groupby(['Day','hum_binary']).count()
aver_hum_london = sum_london_hum/count_london_hum

# %%
aver_hum_london.cnt.plot(
    kind='bar', width=0.85)
plt.xticks(rotation=45)
plt.show()
# edw vlepoume oti to humidity otan einai megalo (panw apo to median =1) epireazei to soukou
# pou oi anthrwpoi exoun tin epologi
# otan einai mikrotero tou median (=0) simenei pws

# %%
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
London['Day'] = London['Day'].astype('category', categories=cats, ordered=True)
# Out:
# /Users/vilvaki/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
London.groupby('Day')['cnt'].mean().plot(
    kind='bar', color='r', width=0.85)
plt.xticks(rotation=45)
plt.show()

# %%
London.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season     Day  hum_binary
# 0         0.0         1.0     3.0  Sunday           1
# 1         0.0         1.0     3.0  Sunday           1
# 2         0.0         1.0     3.0  Sunday           1
# 3         0.0         1.0     3.0  Sunday           1
# 4         0.0         1.0     3.0  Sunday           1

# %% [markdown]
# # DC:

# %%
DC_dataset = pd.read_csv('/Users/vilvaki/Desktop/GA/bikes/bike-sharing-dataset/day.csv')

# %%
DC_dataset.shape
# Out:
# (731, 16)

# %%
DC_dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
DC_dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
DC = pd.read_csv('/Users/vilvaki/Desktop/GA/bikes/bike-sharing-demand/train.csv')

# %%
DC.shape
# Out:
# (10886, 12)

# %%
DC.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
DC.season.value_counts()
# Out:
# 4    2734
# 3    2733
# 2    2733
# 1    2686
# Name: season, dtype: int64

# %%
median_hum_dc = DC.humidity.median()
list_hum_binary_dc = []
for i in DC['humidity']:
    if i > median_hum_dc:
        list_hum_binary_dc.append(1)
    else:
        list_hum_binary_dc.append(0)
DC['hum_binary'] =  list_hum_binary_dc

# %%
DC['datetime'] = pd.to_datetime(DC.datetime)
DC.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# hum_binary             int64
# dtype: object

# %%
DC['Day'] = DC.datetime.dt.weekday_name
aver_hum_dc = DC.groupby(['Day','hum_binary']).sum()/DC.groupby(['Day','hum_binary']).count()
aver_hum_dc['count'].plot(
    kind='bar', width=0.85)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Canada:

# %%
canada = pd.read_csv('/Users/vilvaki/Desktop/GA/bikes/ottawa-bike-counters/ml_friendly_bike_counters.csv')

# %%
canada.head()
# Out:
#   location_name  location_id  count  day  day_of_year  day_of_week  MaxTemp  \
# 0          ALEX            2      0    0            0          4.0     -2.5
# 1          COBY            3      0    0            0          4.0     -2.5
# 2          ORPY           10      0    0            0          4.0     -2.5
# 3          ALEX            2      0    1            1          5.0    -11.9
# 4          COBY            3      0    1            1          5.0    -11.9
#
#    MeanTemp  MinTemp  SnowonGrndcm  TotalPrecipmm  TotalRainmm  TotalSnowcm
# 0      -4.1     -5.7          18.0            5.0          0.0          7.6
# 1      -4.1     -5.7          18.0            5.0          0.0          7.6
# 2      -4.1     -5.7          18.0            5.0          0.0          7.6
# 3     -13.3    -14.6          21.0            1.9          0.0          2.6
# 4     -13.3    -14.6          21.0            1.9          0.0          2.6

# %%
canada.shape
# Out:
# (28786, 13)

# %%
canada.dropna(inplace=True)
canada.isnull().sum()
# Out:
# location_name    0
# location_id      0
# count            0
# day              0
# day_of_year      0
# day_of_week      0
# MaxTemp          0
# MeanTemp         0
# MinTemp          0
# SnowonGrndcm     0
# TotalPrecipmm    0
# TotalRainmm      0
# TotalSnowcm      0
# dtype: int64

# %%
replace_to_days = []

for day_index in canada.day_of_week:
    replace_to_days.append(cats[(int(day_index) - 1) % 7])

canada['Day'] = replace_to_days
canada.Day.value_counts()
# Out:
# Friday       4101
# Tuesday      4094
# Thursday     4091
# Saturday     4091
# Monday       4083
# Wednesday    4080
# Sunday       4077
# Name: Day, dtype: int64

# %%
canada['Day'] = canada['Day'].astype('category', categories=cats, ordered=True)
canada.groupby('Day')['count'].mean().plot(
    kind='bar', color='r', width=0.85)
plt.xticks(rotation=45)
plt.show()

# %%
median_of_mean_temp_canada = canada.MeanTemp.median()

# %%
list_temp_can = []
for i in canada['MeanTemp']:
    if i > median_of_mean_temp_canada:
        list_temp_can.append(1)
    else:
        list_temp_can.append(0)
canada['MeanTemp_binary'] =  list_temp_can

# %%
canada.head()
# Out:
#   location_name  location_id  count  day  day_of_year  day_of_week  MaxTemp  \
# 0          ALEX            2      0    0            0          4.0     -2.5
# 1          COBY            3      0    0            0          4.0     -2.5
# 2          ORPY           10      0    0            0          4.0     -2.5
# 3          ALEX            2      0    1            1          5.0    -11.9
# 4          COBY            3      0    1            1          5.0    -11.9
#
#    MeanTemp  MinTemp  SnowonGrndcm  TotalPrecipmm  TotalRainmm  TotalSnowcm  \
# 0      -4.1     -5.7          18.0            5.0          0.0          7.6
# 1      -4.1     -5.7          18.0            5.0          0.0          7.6
# 2      -4.1     -5.7          18.0            5.0          0.0          7.6
# 3     -13.3    -14.6          21.0            1.9          0.0          2.6
# 4     -13.3    -14.6          21.0            1.9          0.0          2.6
#
#         Day  MeanTemp_binary
# 0  Thursday                0
# 1  Thursday                0
# 2  Thursday                0
# 3    Friday                0
# 4    Friday                0

# %%
aver_temp_can = canada.groupby(['Day','MeanTemp_binary']).sum()/canada.groupby(['Day','MeanTemp_binary']).count()

# %%
aver_temp_can['count'].plot(
    kind='bar', width=0.85)
plt.xticks(rotation=45)
plt.show()

# %%
mean_rain_canada = canada.TotalRainmm.mean()

# %%
list_rain_can = []
for i in canada['TotalRainmm']:
    if i > median_of_mean_temp_canada:
        list_rain_can.append(1)
    else:
        list_rain_can.append(0)
canada['Rain_binary'] =  list_rain_can

# %%
aver_rain_can = canada.groupby(['Day','Rain_binary']).sum()/canada.groupby(['Day','Rain_binary']).count()

# %%
# aver_rain_can['count'].plot(
#     kind='bar', width=0.85)
# plt.xticks(rotation=45)
# plt.show()
